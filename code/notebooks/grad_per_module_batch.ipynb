# %%
import gym
import numpy as np
import torch
import wandb
import pandas as pd

import argparse
import pickle
import random
import sys

sys.path.append('/Users/shiro/research/projects/rl-nlp/can-wikipedia-help-offline-rl/code')

from decision_transformer.evaluation.evaluate_episodes import (
    evaluate_episode,
    evaluate_episode_rtg,
)
from decision_transformer.models.decision_transformer import DecisionTransformer
from decision_transformer.models.mlp_bc import MLPBCModel
from decision_transformer.training.act_trainer import ActTrainer
from decision_transformer.training.seq_trainer import SequenceTrainer

from utils import get_optimizer
import os

from tqdm.notebook import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("ticks")
sns.set_context("paper", 1.5, {"lines.linewidth": 2})

# %%
def discount_cumsum(x, gamma):
    discount_cumsum = np.zeros_like(x)
    discount_cumsum[-1] = x[-1]
    for t in reversed(range(x.shape[0] - 1)):
        discount_cumsum[t] = x[t] + gamma * discount_cumsum[t + 1]
    return discount_cumsum

def prepare_data(variant):
    env_name, dataset = variant["env"], variant["dataset"]
    model_type = variant["model_type"]
    exp_prefix = 'gym-experiment'
    group_name = f"{exp_prefix}-{env_name}-{dataset}"
    exp_prefix = f"{group_name}-{random.randint(int(1e5), int(1e6) - 1)}"

    if env_name == "hopper":
        env = gym.make("Hopper-v3")
        max_ep_len = 1000
        env_targets = [3600, 1800]  # evaluation conditioning targets
        scale = 1000.0  # normalization for rewards/returns
    elif env_name == "halfcheetah":
        env = gym.make("HalfCheetah-v3")
        max_ep_len = 1000
        env_targets = [12000, 6000]
        scale = 1000.0
    elif env_name == "walker2d":
        env = gym.make("Walker2d-v3")
        max_ep_len = 1000
        env_targets = [5000, 2500]
        scale = 1000.0
    elif env_name == "reacher2d":
        from decision_transformer.envs.reacher_2d import Reacher2dEnv

        env = Reacher2dEnv()
        max_ep_len = 100
        env_targets = [76, 40]
        scale = 10.0
    else:
        raise NotImplementedError

    if model_type == "bc":
        env_targets = env_targets[
            :1
        ]  # since BC ignores target, no need for different evaluations

    state_dim = env.observation_space.shape[0]
    act_dim = env.action_space.shape[0]

    # load dataset
    dataset_path = f"../data/{env_name}-{dataset}-v2.pkl"
    with open(dataset_path, "rb") as f:
        trajectories = pickle.load(f)

    # save all path information into separate lists
    mode = variant.get("mode", "normal")
    states, traj_lens, returns = [], [], []
    for path in trajectories:
        if mode == "delayed":  # delayed: all rewards moved to end of trajectory
            path["rewards"][-1] = path["rewards"].sum()
            path["rewards"][:-1] = 0.0
        states.append(path["observations"])
        traj_lens.append(len(path["observations"]))
        returns.append(path["rewards"].sum())
    traj_lens, returns = np.array(traj_lens), np.array(returns)

    # used for input normalization
    states = np.concatenate(states, axis=0)
    state_mean, state_std = np.mean(states, axis=0), np.std(states, axis=0) + 1e-6

    num_timesteps = sum(traj_lens)

    print("=" * 50)
    print(f"Starting new experiment: {env_name} {dataset}")
    print(f"{len(traj_lens)} trajectories, {num_timesteps} timesteps found")
    print(f"Average return: {np.mean(returns):.2f}, std: {np.std(returns):.2f}")
    print(f"Max return: {np.max(returns):.2f}, min: {np.min(returns):.2f}")
    print("=" * 50)
    
    pct_traj = variant.get("pct_traj", 1.0)

    # only train on top pct_traj trajectories (for %BC experiment)
    num_timesteps = max(int(pct_traj * num_timesteps), 1)
    sorted_inds = np.argsort(returns)  # lowest to highest
    num_trajectories = 1
    timesteps = traj_lens[sorted_inds[-1]]
    ind = len(trajectories) - 2
    while ind >= 0 and timesteps + traj_lens[sorted_inds[ind]] < num_timesteps:
        timesteps += traj_lens[sorted_inds[ind]]
        num_trajectories += 1
        ind -= 1
    sorted_inds = sorted_inds[-num_trajectories:]

    # used to reweight sampling so we sample according to timesteps instead of trajectories
    p_sample = traj_lens[sorted_inds] / sum(traj_lens[sorted_inds])
    
    return trajectories, sorted_inds, state_dim, act_dim, max_ep_len, state_mean, state_std, num_trajectories, p_sample, scale

def get_batch(
    batch_size, 
    max_len,
    trajectories,
    sorted_inds,
    state_dim,
    act_dim,
    max_ep_len,
    state_mean,
    state_std,
    num_trajectories,
    p_sample,
    scale,
    device
    ):
    batch_inds = np.random.choice(
        np.arange(num_trajectories),
        size=batch_size,
        replace=True,
        p=p_sample,  # reweights so we sample according to timesteps
    )

    s, a, r, d, rtg, timesteps, mask = [], [], [], [], [], [], []
    for i in range(batch_size):
        traj = trajectories[int(sorted_inds[batch_inds[i]])]
        si = random.randint(0, traj["rewards"].shape[0] - 1)

        # get sequences from dataset
        s.append(traj["observations"][si : si + max_len].reshape(1, -1, state_dim))
        a.append(traj["actions"][si : si + max_len].reshape(1, -1, act_dim))
        r.append(traj["rewards"][si : si + max_len].reshape(1, -1, 1))
        if "terminals" in traj:
            d.append(traj["terminals"][si : si + max_len].reshape(1, -1))
        else:
            d.append(traj["dones"][si : si + max_len].reshape(1, -1))
        timesteps.append(np.arange(si, si + s[-1].shape[1]).reshape(1, -1))
        timesteps[-1][timesteps[-1] >= max_ep_len] = (
            max_ep_len - 1
        )  # padding cutoff
        rtg.append(
            discount_cumsum(traj["rewards"][si:], gamma=1.0)[
                : s[-1].shape[1] + 1
            ].reshape(1, -1, 1)
        )
        if rtg[-1].shape[1] <= s[-1].shape[1]:
            rtg[-1] = np.concatenate([rtg[-1], np.zeros((1, 1, 1))], axis=1)

        # padding and state + reward normalization
        tlen = s[-1].shape[1]
        s[-1] = np.concatenate(
            [np.zeros((1, max_len - tlen, state_dim)), s[-1]], axis=1
        )
        s[-1] = (s[-1] - state_mean) / state_std
        a[-1] = np.concatenate(
            [np.ones((1, max_len - tlen, act_dim)) * -10.0, a[-1]], axis=1
        )
        r[-1] = np.concatenate([np.zeros((1, max_len - tlen, 1)), r[-1]], axis=1)
        d[-1] = np.concatenate([np.ones((1, max_len - tlen)) * 2, d[-1]], axis=1)
        rtg[-1] = (
            np.concatenate([np.zeros((1, max_len - tlen, 1)), rtg[-1]], axis=1)
            / scale
        )
        timesteps[-1] = np.concatenate(
            [np.zeros((1, max_len - tlen)), timesteps[-1]], axis=1
        )
        mask.append(
            np.concatenate(
                [np.zeros((1, max_len - tlen)), np.ones((1, tlen))], axis=1
            )
        )

    s = torch.from_numpy(np.concatenate(s, axis=0)).to(
        dtype=torch.float32, device=device
    )
    a = torch.from_numpy(np.concatenate(a, axis=0)).to(
        dtype=torch.float32, device=device
    )
    r = torch.from_numpy(np.concatenate(r, axis=0)).to(
        dtype=torch.float32, device=device
    )
    d = torch.from_numpy(np.concatenate(d, axis=0)).to(
        dtype=torch.long, device=device
    )
    rtg = torch.from_numpy(np.concatenate(rtg, axis=0)).to(
        dtype=torch.float32, device=device
    )
    timesteps = torch.from_numpy(np.concatenate(timesteps, axis=0)).to(
        dtype=torch.long, device=device
    )
    mask = torch.from_numpy(np.concatenate(mask, axis=0)).to(device=device)

    return s, a, r, d, rtg, timesteps, mask

# %%
seed=666
epoch=1
env_name='hopper'
reward_state_action = 'state'
model_name = 'igpt'

torch.manual_seed(seed)

dataset_name = 'medium'

# model_names = ['gpt2', 'igpt', 'dt']  # ['gpt2', 'igpt', 'dt']
grad_norms_list = []


if model_name == 'gpt2':
    pretrained_lm1 = 'gpt2'
elif model_name == 'clip':
    pretrained_lm1 = 'openai/clip-vit-base-patch32'
elif model_name == 'igpt':
    pretrained_lm1 = 'openai/imagegpt-small'
elif model_name == 'dt':
    pretrained_lm1 = False

variant = {
    'embed_dim': 768,
    'n_layer': 12,
    'n_head': 1,
    'activation_function': 'relu',
    'dropout': 0.2, # 0.1
    'load_checkpoint': False if epoch==0 else f'../checkpoints/{model_name}_medium_{env_name}_666/model_{epoch}.pt',
    'seed': seed,
    'outdir': f"checkpoints/{model_name}_{dataset_name}_{env_name}_{seed}",
    'env': env_name,
    'dataset': dataset_name,
    'model_type': 'dt',
    'K': 20, # 2
    'pct_traj': 1.0,
    'batch_size': 100,  # 64
    'num_eval_episodes': 100,
    'max_iters': 40,
    'num_steps_per_iter': 2500,
    'pretrained_lm': pretrained_lm1,
    'gpt_kmeans': None,
    'kmeans_cache': None,
    'frozen': False,
    'extend_positions': False,
    'share_input_output_proj': True
}

os.makedirs(variant["outdir"], exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

trajectories, sorted_inds, state_dim, act_dim, max_ep_len, state_mean, state_std, num_trajectories, p_sample, scale = prepare_data(variant)

K = variant["K"]
batch_size = variant["batch_size"]

loss_fn = lambda s_hat, a_hat, r_hat, s, a, r: torch.mean((a_hat - a) ** 2)

model = DecisionTransformer(
    args=variant,
    state_dim=state_dim,
    act_dim=act_dim,
    max_length=K,
    max_ep_len=max_ep_len,
    hidden_size=variant["embed_dim"],
    n_layer=variant["n_layer"],
    n_head=variant["n_head"],
    n_inner=4 * variant["embed_dim"],
    activation_function=variant["activation_function"],
    n_positions=1024,
    resid_pdrop=variant["dropout"],
    attn_pdrop=0.1,
)
if variant["load_checkpoint"]:
    state_dict = torch.load(variant["load_checkpoint"], map_location=torch.device('cpu'))
    model.load_state_dict(state_dict)
    print(f"Loaded from {variant['load_checkpoint']}")

# model.eval()

# grad = {}
# def get_grad(name):
#     def hook(model, input, output):
#         grad[name] = output.detach()
#     return hook

# for block_id in range(len(model.transformer.h)):
#     model.transformer.h[block_id].ln_1.register_backward_hook(get_grad(f'{block_id}.ln_1'))
#     model.transformer.h[block_id].attn.c_attn.register_backward_hook(get_grad(f'{block_id}.attn.c_attn'))
#     model.transformer.h[block_id].attn.c_proj.register_backward_hook(get_grad(f'{block_id}.attn.c_proj'))
#     model.transformer.h[block_id].attn.attn_dropout.register_backward_hook(get_grad(f'{block_id}.attn.attn_dropout'))
#     model.transformer.h[block_id].attn.resid_dropout.register_backward_hook(get_grad(f'{block_id}.attn.resid_dropout'))
#     model.transformer.h[block_id].ln_2.register_backward_hook(get_grad(f'{block_id}.ln_2'))
#     model.transformer.h[block_id].mlp.c_fc.register_backward_hook(get_grad(f'{block_id}.mlp.c_fc'))
#     model.transformer.h[block_id].mlp.c_proj.register_backward_hook(get_grad(f'{block_id}.mlp.c_proj'))
#     model.transformer.h[block_id].mlp.act.register_backward_hook(get_grad(f'{block_id}.mlp.act'))
#     model.transformer.h[block_id].mlp.dropout.register_backward_hook(get_grad(f'{block_id}.mlp.dropout'))
states, actions, rewards, dones, rtg, timesteps, attention_mask = get_batch(batch_size, 
                                                                            K,
                                                                            trajectories,
                                                                            sorted_inds,
                                                                            state_dim,
                                                                            act_dim,
                                                                            max_ep_len,
                                                                            state_mean,
                                                                            state_std,
                                                                            num_trajectories,
                                                                            p_sample,
                                                                            scale,
                                                                            device
                                                                            )
action_target = torch.clone(actions)
grads_list = []

for batch_id in tqdm(range(batch_size)):
    ##### 勾配計算 #####
    action_target_batch = action_target[batch_id, :, :].unsqueeze(0)

    state_preds, action_preds, reward_preds, all_embs = model.forward(
        states[batch_id, :, :].unsqueeze(0),
        actions[batch_id, :, :].unsqueeze(0),
        rewards[batch_id, :, :].unsqueeze(0),
        rtg[batch_id, :-1].unsqueeze(0),
        timesteps[batch_id, :].unsqueeze(0),
        attention_mask=attention_mask[batch_id, :].unsqueeze(0),
    )

    act_dim = action_preds.shape[2]
    action_preds = action_preds.reshape(-1, act_dim)[attention_mask[batch_id, :].unsqueeze(0).reshape(-1) > 0]
    action_target_batch = action_target_batch.reshape(-1, act_dim)[
        attention_mask[batch_id, :].unsqueeze(0).reshape(-1) > 0
    ]

    model.zero_grad()
    loss = loss_fn(
        None,
        action_preds,
        None,
        None,
        action_target_batch,
        None,
    )
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), .25)

    grad_norm = {}
    for name, param in model.transformer.h.named_parameters():
        grad_norm[name] = torch.norm(param.grad.view(-1)).numpy()
# Out:
# ==================================================
# Starting new experiment: hopper medium
# 2186 trajectories, 999906 timesteps found
# Average return: 1422.06, std: 378.95
# Max return: 3222.36, min: 315.87
# ==================================================
# Loading from pretrained
# You are using a model of type imagegpt to instantiate a model of type gpt2. This is not supported for all configurations of models and can yield errors.
# Some weights of the model checkpoint at openai/imagegpt-small were not used when initializing GPT2Model: ['lm_head.weight']
# - This IS expected if you are initializing GPT2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing GPT2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of GPT2Model were not initialized from the model checkpoint at openai/imagegpt-small and are newly initialized: ['transformer.h.7.ln_1.bias', 'transformer.h.22.ln_1.bias', 'transformer.h.16.ln_2.bias', 'transformer.h.0.ln_1.bias', 'transformer.h.5.ln_1.bias', 'transformer.h.1.ln_2.bias', 'transformer.h.19.ln_1.bias', 'transformer.h.13.ln_2.bias', 'transformer.h.9.ln_1.bias', 'transformer.h.10.ln_1.bias', 'transformer.h.12.ln_2.bias', 'transformer.h.0.ln_2.bias', 'transformer.h.16.ln_1.bias', 'transformer.h.18.ln_2.bias', 'transformer.h.6.ln_2.bias', 'transformer.h.17.ln_1.bias', 'transformer.h.13.ln_1.bias', 'transformer.h.21.ln_1.bias', 'transformer.h.14.ln_2.bias', 'transformer.h.15.ln_2.bias', 'transformer.h.23.ln_2.bias', 'transformer.h.6.ln_1.bias', 'transformer.h.15.ln_1.bias', 'transformer.h.17.ln_2.bias', 'transformer.h.20.ln_2.bias', 'transformer.h.19.ln_2.bias', 'transformer.h.3.ln_1.bias', 'transformer.h.2.ln_1.bias', 'transformer.h.10.ln_2.bias', 'transformer.h.3.ln_2.bias', 'transformer.h.9.ln_2.bias', 'transformer.ln_f.bias', 'transformer.h.22.ln_2.bias', 'transformer.h.21.ln_2.bias', 'transformer.h.18.ln_1.bias', 'transformer.h.8.ln_1.bias', 'transformer.h.7.ln_2.bias', 'transformer.h.4.ln_1.bias', 'transformer.h.12.ln_1.bias', 'transformer.h.20.ln_1.bias', 'transformer.h.23.ln_1.bias', 'transformer.h.5.ln_2.bias', 'transformer.h.11.ln_1.bias', 'transformer.h.4.ln_2.bias', 'transformer.h.2.ln_2.bias', 'transformer.h.8.ln_2.bias', 'transformer.h.1.ln_1.bias', 'transformer.h.11.ln_2.bias', 'transformer.h.14.ln_1.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loaded from ../checkpoints/igpt_medium_hopper_666/model_1.pt
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/shiro/miniforge3/envs/wikirl-gym/lib/python3.8/site-packages/torch/nn/functional.py:1933: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
plt.figure(figsize=(20, 4))
plt.bar(x=range(len(grad_norm)), height=list(grad_norm.values()), color=(0.372, 0.537, 0.537))
# plt.xticks([], [])
plt.xlabel('Parameter of Each Layer', fontsize=20)
plt.ylabel('Clipped Gradient Norm', fontsize=20)
plt.title('Gradient Norm of Each Parameter', fontsize=20)
plt.ylim(0, 0.25)
plt.tight_layout()
plt.savefig(f'figs/gradnorm_perparam_{epoch}_igpt_{env_name}_{dataset_name}_{seed}_{reward_state_action}.pdf')
plt.show()

# %%
df = pd.DataFrame([grad_norm]).astype(float)
df
# Out:
#    0.ln_1.weight  0.ln_1.bias  0.attn.c_attn.weight  0.attn.c_attn.bias  \
# 0       0.150526     0.196951              0.003553             0.00385
#
#    0.attn.c_proj.weight  0.attn.c_proj.bias  0.ln_2.weight  0.ln_2.bias  \
# 0              0.002023            0.000234       0.002447      0.00378
#
#    0.mlp.c_fc.weight  0.mlp.c_fc.bias  ...  23.attn.c_attn.weight  \
# 0           0.000865         0.000184  ...               0.000002
#
#    23.attn.c_attn.bias  23.attn.c_proj.weight  23.attn.c_proj.bias  \
# 0         1.635610e-07               0.000001         1.262315e-08
#
#    23.ln_2.weight  23.ln_2.bias  23.mlp.c_fc.weight  23.mlp.c_fc.bias  \
# 0        0.000004      0.000005            0.000002      2.078597e-07
#
#    23.mlp.c_proj.weight  23.mlp.c_proj.bias
# 0              0.000003        1.226672e-08
#
# [1 rows x 288 columns]

# %%
df = pd.DataFrame([grad_norm]).astype(float)
x = np.linspace(0, 1, len(grad_norm))#[(i+1)/len(grad_norm) for i in range(len(grad_norm))]
df.plot.barh(stacked=True, figsize=(24, 40))  # color=plt.cm.Blues_r(x), 
plt.legend(loc="lower left", ncol=12)
plt.show()

# %%
grad_norm_others = {
    '0.ln_1.weight': 0,
    '0.ln_1.bias': 0,
    'others': 0
}
total = np.sum(list(grad_norm.values()))
for key, value in grad_norm.items():
    if key == '0.ln_1.weight' or key == '0.ln_1.bias':
        grad_norm_others[key] = value / total
    else:
        grad_norm_others['others'] += value / total

total = np.sum(grad_norm_others.values())


df_others = pd.DataFrame([grad_norm_others]).astype(float)
x = np.linspace(0, 1, len(grad_norm_others))#[(i+1)/len(grad_norm) for i in range(len(grad_norm))]
df_others.plot.barh(stacked=True, figsize=(10, 5), color=[(0.372, 0.537, 0.537), (0.627, 0.352, 0.470), (0.733, 0.737, 0.870)], fontsize=12)  # color=plt.cm.Blues_r(x), 
plt.yticks([], [])
plt.xlim(0, 1)
plt.title('Gradient Norm per Parameter', fontsize=12)
plt.xlabel('Clipped Gradient Norm Ratio', fontsize=12)
plt.legend(loc="lower left", ncol=12, fontsize=12)
plt.savefig(f'figs/gradnorm_perparam_ratio_{epoch}_igpt_{env_name}_{dataset_name}_{seed}_{reward_state_action}.pdf')
plt.show()

# %%
total = np.sum(list(grad_norm.values()))
total
# Out:
# 0.4020847

# %%
grad_norm_others
# Out:
# {'0.ln_1.weight': array(0.15052631, dtype=float32),
#  '0.ln_1.bias': array(0.19695084, dtype=float32),
#  'others': 0.05460753018395437}

# %%
grad_norm
# Out:
# {'0.ln_1.weight': array(0.15052631, dtype=float32),
#  '0.ln_1.bias': array(0.19695084, dtype=float32),
#  '0.attn.c_attn.weight': array(0.00355266, dtype=float32),
#  '0.attn.c_attn.bias': array(0.00384979, dtype=float32),
#  '0.attn.c_proj.weight': array(0.00202323, dtype=float32),
#  '0.attn.c_proj.bias': array(0.00023447, dtype=float32),
#  '0.ln_2.weight': array(0.00244699, dtype=float32),
#  '0.ln_2.bias': array(0.00378013, dtype=float32),
#  '0.mlp.c_fc.weight': array(0.00086475, dtype=float32),
#  '0.mlp.c_fc.bias': array(0.0001842, dtype=float32),
#  '0.mlp.c_proj.weight': array(0.00097358, dtype=float32),
#  '0.mlp.c_proj.bias': array(9.543335e-06, dtype=float32),
#  '1.ln_1.weight': array(0.00104625, dtype=float32),
#  '1.ln_1.bias': array(0.00136496, dtype=float32),
#  '1.attn.c_attn.weight': array(0.00169627, dtype=float32),
#  '1.attn.c_attn.bias': array(9.057235e-05, dtype=float32),
#  '1.attn.c_proj.weight': array(0.00166962, dtype=float32),
#  '1.attn.c_proj.bias': array(3.947326e-06, dtype=float32),
#  '1.ln_2.weight': array(0.00032652, dtype=float32),
#  '1.ln_2.bias': array(0.00089051, dtype=float32),
#  '1.mlp.c_fc.weight': array(0.00043147, dtype=float32),
#  '1.mlp.c_fc.bias': array(4.7602887e-05, dtype=float32),
#  '1.mlp.c_proj.weight': array(0.000447, dtype=float32),
#  '1.mlp.c_proj.bias': array(3.6439867e-06, dtype=float32),
#  '2.ln_1.weight': array(0.001934, dtype=float32),
#  '2.ln_1.bias': array(0.00363587, dtype=float32),
#  '2.attn.c_attn.weight': array(0.00066349, dtype=float32),
#  '2.attn.c_attn.bias': array(7.864863e-05, dtype=float32),
#  '2.attn.c_proj.weight': array(0.00069305, dtype=float32),
#  '2.attn.c_proj.bias': array(5.017842e-06, dtype=float32),
#  '2.ln_2.weight': array(0.00063624, dtype=float32),
#  '2.ln_2.bias': array(0.00258687, dtype=float32),
#  '2.mlp.c_fc.weight': array(0.00084477, dtype=float32),
#  '2.mlp.c_fc.bias': array(7.2735405e-05, dtype=float32),
#  '2.mlp.c_proj.weight': array(0.0006375, dtype=float32),
#  '2.mlp.c_proj.bias': array(2.4653946e-06, dtype=float32),
#  '3.ln_1.weight': array(0.00149469, dtype=float32),
#  '3.ln_1.bias': array(0.0014145, dtype=float32),
#  '3.attn.c_attn.weight': array(0.00072266, dtype=float32),
#  '3.attn.c_attn.bias': array(6.321475e-05, dtype=float32),
#  '3.attn.c_proj.weight': array(0.00050596, dtype=float32),
#  '3.attn.c_proj.bias': array(1.4565544e-06, dtype=float32),
#  '3.ln_2.weight': array(0.00032702, dtype=float32),
#  '3.ln_2.bias': array(0.00063512, dtype=float32),
#  '3.mlp.c_fc.weight': array(0.00076399, dtype=float32),
#  '3.mlp.c_fc.bias': array(3.1334643e-05, dtype=float32),
#  '3.mlp.c_proj.weight': array(0.0007481, dtype=float32),
#  '3.mlp.c_proj.bias': array(1.0798611e-06, dtype=float32),
#  '4.ln_1.weight': array(0.0002814, dtype=float32),
#  '4.ln_1.bias': array(0.00048418, dtype=float32),
#  '4.attn.c_attn.weight': array(0.0006317, dtype=float32),
#  '4.attn.c_attn.bias': array(2.9040526e-05, dtype=float32),
#  '4.attn.c_proj.weight': array(0.00060087, dtype=float32),
#  '4.attn.c_proj.bias': array(1.0122177e-06, dtype=float32),
#  '4.ln_2.weight': array(0.00030441, dtype=float32),
#  '4.ln_2.bias': array(0.00047064, dtype=float32),
#  '4.mlp.c_fc.weight': array(0.00054514, dtype=float32),
#  '4.mlp.c_fc.bias': array(2.6535261e-05, dtype=float32),
#  '4.mlp.c_proj.weight': array(0.00058187, dtype=float32),
#  '4.mlp.c_proj.bias': array(9.603029e-07, dtype=float32),
#  '5.ln_1.weight': array(0.00040969, dtype=float32),
#  '5.ln_1.bias': array(0.00081643, dtype=float32),
#  '5.attn.c_attn.weight': array(0.00043856, dtype=float32),
#  '5.attn.c_attn.bias': array(2.7286827e-05, dtype=float32),
#  '5.attn.c_proj.weight': array(0.0002472, dtype=float32),
#  '5.attn.c_proj.bias': array(5.889246e-07, dtype=float32),
#  '5.ln_2.weight': array(0.00016724, dtype=float32),
#  '5.ln_2.bias': array(0.00029852, dtype=float32),
#  '5.mlp.c_fc.weight': array(0.00027726, dtype=float32),
#  '5.mlp.c_fc.bias': array(1.5594716e-05, dtype=float32),
#  '5.mlp.c_proj.weight': array(0.00034651, dtype=float32),
#  '5.mlp.c_proj.bias': array(6.649731e-07, dtype=float32),
#  '6.ln_1.weight': array(0.00027279, dtype=float32),
#  '6.ln_1.bias': array(0.00049223, dtype=float32),
#  '6.attn.c_attn.weight': array(0.00061888, dtype=float32),
#  '6.attn.c_attn.bias': array(3.2102966e-05, dtype=float32),
#  '6.attn.c_proj.weight': array(5.7204656e-05, dtype=float32),
#  '6.attn.c_proj.bias': array(1.3692511e-07, dtype=float32),
#  '6.ln_2.weight': array(2.7088283e-05, dtype=float32),
#  '6.ln_2.bias': array(7.927949e-05, dtype=float32),
#  '6.mlp.c_fc.weight': array(4.4805536e-05, dtype=float32),
#  '6.mlp.c_fc.bias': array(4.0583855e-06, dtype=float32),
#  '6.mlp.c_proj.weight': array(4.4706194e-05, dtype=float32),
#  '6.mlp.c_proj.bias': array(1.356018e-07, dtype=float32),
#  '7.ln_1.weight': array(9.59777e-05, dtype=float32),
#  '7.ln_1.bias': array(9.238185e-05, dtype=float32),
#  '7.attn.c_attn.weight': array(0.00010131, dtype=float32),
#  '7.attn.c_attn.bias': array(4.956424e-06, dtype=float32),
#  '7.attn.c_proj.weight': array(2.0944284e-05, dtype=float32),
#  '7.attn.c_proj.bias': array(6.3964634e-08, dtype=float32),
#  '7.ln_2.weight': array(1.7184051e-05, dtype=float32),
#  '7.ln_2.bias': array(3.5275112e-05, dtype=float32),
#  '7.mlp.c_fc.weight': array(2.373793e-05, dtype=float32),
#  '7.mlp.c_fc.bias': array(1.8451899e-06, dtype=float32),
#  '7.mlp.c_proj.weight': array(2.2964807e-05, dtype=float32),
#  '7.mlp.c_proj.bias': array(6.9824644e-08, dtype=float32),
#  '8.ln_1.weight': array(0.00010583, dtype=float32),
#  '8.ln_1.bias': array(5.6545174e-05, dtype=float32),
#  '8.attn.c_attn.weight': array(5.9655376e-05, dtype=float32),
#  '8.attn.c_attn.bias': array(3.6964864e-06, dtype=float32),
#  '8.attn.c_proj.weight': array(1.3004948e-05, dtype=float32),
#  '8.attn.c_proj.bias': array(3.5047066e-08, dtype=float32),
#  '8.ln_2.weight': array(1.7655144e-05, dtype=float32),
#  '8.ln_2.bias': array(2.299733e-05, dtype=float32),
#  '8.mlp.c_fc.weight': array(1.3580856e-05, dtype=float32),
#  '8.mlp.c_fc.bias': array(1.1340579e-06, dtype=float32),
#  '8.mlp.c_proj.weight': array(1.1974848e-05, dtype=float32),
#  '8.mlp.c_proj.bias': array(3.7234045e-08, dtype=float32),
#  '9.ln_1.weight': array(1.8889701e-05, dtype=float32),
#  '9.ln_1.bias': array(2.9404242e-05, dtype=float32),
#  '9.attn.c_attn.weight': array(2.7570897e-05, dtype=float32),
#  '9.attn.c_attn.bias': array(1.7268442e-06, dtype=float32),
#  '9.attn.c_proj.weight': array(1.0036159e-05, dtype=float32),
#  '9.attn.c_proj.bias': array(2.7986744e-08, dtype=float32),
#  '9.ln_2.weight': array(1.0739784e-05, dtype=float32),
#  '9.ln_2.bias': array(1.570447e-05, dtype=float32),
#  '9.mlp.c_fc.weight': array(9.8253295e-06, dtype=float32),
#  '9.mlp.c_fc.bias': array(9.411863e-07, dtype=float32),
#  '9.mlp.c_proj.weight': array(8.816883e-06, dtype=float32),
#  '9.mlp.c_proj.bias': array(3.0430325e-08, dtype=float32),
#  '10.ln_1.weight': array(3.9767074e-05, dtype=float32),
#  '10.ln_1.bias': array(3.3856286e-05, dtype=float32),
#  '10.attn.c_attn.weight': array(3.750446e-05, dtype=float32),
#  '10.attn.c_attn.bias': array(2.2422619e-06, dtype=float32),
#  '10.attn.c_proj.weight': array(4.469993e-06, dtype=float32),
#  '10.attn.c_proj.bias': array(1.695237e-08, dtype=float32),
#  '10.ln_2.weight': array(3.8034775e-06, dtype=float32),
#  '10.ln_2.bias': array(7.8046005e-06, dtype=float32),
#  '10.mlp.c_fc.weight': array(4.172684e-06, dtype=float32),
#  '10.mlp.c_fc.bias': array(4.6551293e-07, dtype=float32),
#  '10.mlp.c_proj.weight': array(4.4232584e-06, dtype=float32),
#  '10.mlp.c_proj.bias': array(1.8286004e-08, dtype=float32),
#  '11.ln_1.weight': array(6.959068e-06, dtype=float32),
#  '11.ln_1.bias': array(1.0561451e-05, dtype=float32),
#  '11.attn.c_attn.weight': array(1.0086374e-05, dtype=float32),
#  '11.attn.c_attn.bias': array(7.3591946e-07, dtype=float32),
#  '11.attn.c_proj.weight': array(5.009933e-06, dtype=float32),
#  '11.attn.c_proj.bias': array(1.7685464e-08, dtype=float32),
#  '11.ln_2.weight': array(3.5194716e-06, dtype=float32),
#  '11.ln_2.bias': array(7.3418846e-06, dtype=float32),
#  '11.mlp.c_fc.weight': array(4.1018834e-06, dtype=float32),
#  '11.mlp.c_fc.bias': array(4.5911315e-07, dtype=float32),
#  '11.mlp.c_proj.weight': array(4.3766727e-06, dtype=float32),
#  '11.mlp.c_proj.bias': array(1.8766864e-08, dtype=float32),
#  '12.ln_1.weight': array(1.51920085e-05, dtype=float32),
#  '12.ln_1.bias': array(1.065203e-05, dtype=float32),
#  '12.attn.c_attn.weight': array(1.0708404e-05, dtype=float32),
#  '12.attn.c_attn.bias': array(7.263349e-07, dtype=float32),
#  '12.attn.c_proj.weight': array(4.127184e-06, dtype=float32),
#  '12.attn.c_proj.bias': array(1.7105437e-08, dtype=float32),
#  '12.ln_2.weight': array(3.8968756e-06, dtype=float32),
#  '12.ln_2.bias': array(6.4146625e-06, dtype=float32),
#  '12.mlp.c_fc.weight': array(3.687156e-06, dtype=float32),
#  '12.mlp.c_fc.bias': array(3.970372e-07, dtype=float32),
#  '12.mlp.c_proj.weight': array(3.841535e-06, dtype=float32),
#  '12.mlp.c_proj.bias': array(1.8274172e-08, dtype=float32),
#  '13.ln_1.weight': array(5.8065425e-06, dtype=float32),
#  '13.ln_1.bias': array(8.300896e-06, dtype=float32),
#  '13.attn.c_attn.weight': array(9.724534e-06, dtype=float32),
#  '13.attn.c_attn.bias': array(6.128731e-07, dtype=float32),
#  '13.attn.c_proj.weight': array(4.120592e-06, dtype=float32),
#  '13.attn.c_proj.bias': array(1.7645315e-08, dtype=float32),
#  '13.ln_2.weight': array(3.7387163e-06, dtype=float32),
#  '13.ln_2.bias': array(5.699158e-06, dtype=float32),
#  '13.mlp.c_fc.weight': array(3.815061e-06, dtype=float32),
#  '13.mlp.c_fc.bias': array(3.8250766e-07, dtype=float32),
#  '13.mlp.c_proj.weight': array(3.988432e-06, dtype=float32),
#  '13.mlp.c_proj.bias': array(1.7890114e-08, dtype=float32),
#  '14.ln_1.weight': array(1.251882e-05, dtype=float32),
#  '14.ln_1.bias': array(1.4948796e-05, dtype=float32),
#  '14.attn.c_attn.weight': array(1.4360217e-05, dtype=float32),
#  '14.attn.c_attn.bias': array(1.0101489e-06, dtype=float32),
#  '14.attn.c_proj.weight': array(2.7312321e-06, dtype=float32),
#  '14.attn.c_proj.bias': array(1.4304118e-08, dtype=float32),
#  '14.ln_2.weight': array(5.1452344e-06, dtype=float32),
#  '14.ln_2.bias': array(4.058295e-06, dtype=float32),
#  '14.mlp.c_fc.weight': array(3.1590887e-06, dtype=float32),
#  '14.mlp.c_fc.bias': array(2.9858668e-07, dtype=float32),
#  '14.mlp.c_proj.weight': array(3.5530502e-06, dtype=float32),
#  '14.mlp.c_proj.bias': array(1.4913255e-08, dtype=float32),
#  '15.ln_1.weight': array(4.7827916e-06, dtype=float32),
#  '15.ln_1.bias': array(5.5732253e-06, dtype=float32),
#  '15.attn.c_attn.weight': array(8.9810665e-06, dtype=float32),
#  '15.attn.c_attn.bias': array(4.5705525e-07, dtype=float32),
#  '15.attn.c_proj.weight': array(2.958769e-06, dtype=float32),
#  '15.attn.c_proj.bias': array(1.4389114e-08, dtype=float32),
#  '15.ln_2.weight': array(2.1259136e-06, dtype=float32),
#  '15.ln_2.bias': array(3.900026e-06, dtype=float32),
#  '15.mlp.c_fc.weight': array(2.904818e-06, dtype=float32),
#  '15.mlp.c_fc.bias': array(2.73698e-07, dtype=float32),
#  '15.mlp.c_proj.weight': array(3.101746e-06, dtype=float32),
#  '15.mlp.c_proj.bias': array(1.4908961e-08, dtype=float32),
#  '16.ln_1.weight': array(2.3674054e-05, dtype=float32),
#  '16.ln_1.bias': array(1.1845678e-05, dtype=float32),
#  '16.attn.c_attn.weight': array(1.2391914e-05, dtype=float32),
#  '16.attn.c_attn.bias': array(8.066803e-07, dtype=float32),
#  '16.attn.c_proj.weight': array(1.7712943e-06, dtype=float32),
#  '16.attn.c_proj.bias': array(1.3635166e-08, dtype=float32),
#  '16.ln_2.weight': array(4.060227e-06, dtype=float32),
#  '16.ln_2.bias': array(3.1112302e-06, dtype=float32),
#  '16.mlp.c_fc.weight': array(2.4543965e-06, dtype=float32),
#  '16.mlp.c_fc.bias': array(2.3202584e-07, dtype=float32),
#  '16.mlp.c_proj.weight': array(2.6619487e-06, dtype=float32),
#  '16.mlp.c_proj.bias': array(1.418699e-08, dtype=float32),
#  '17.ln_1.weight': array(9.576335e-06, dtype=float32),
#  '17.ln_1.bias': array(5.7913694e-06, dtype=float32),
#  '17.attn.c_attn.weight': array(6.781725e-06, dtype=float32),
#  '17.attn.c_attn.bias': array(4.5678308e-07, dtype=float32),
#  '17.attn.c_proj.weight': array(2.4188892e-06, dtype=float32),
#  '17.attn.c_proj.bias': array(1.3898879e-08, dtype=float32),
#  '17.ln_2.weight': array(3.3461372e-06, dtype=float32),
#  '17.ln_2.bias': array(3.0056042e-06, dtype=float32),
#  '17.mlp.c_fc.weight': array(2.454859e-06, dtype=float32),
#  '17.mlp.c_fc.bias': array(2.2801494e-07, dtype=float32),
#  '17.mlp.c_proj.weight': array(2.5291874e-06, dtype=float32),
#  '17.mlp.c_proj.bias': array(1.4411483e-08, dtype=float32),
#  '18.ln_1.weight': array(3.4880054e-06, dtype=float32),
#  '18.ln_1.bias': array(4.496769e-06, dtype=float32),
#  '18.attn.c_attn.weight': array(4.27357e-06, dtype=float32),
#  '18.attn.c_attn.bias': array(3.2483453e-07, dtype=float32),
#  '18.attn.c_proj.weight': array(1.7394705e-06, dtype=float32),
#  '18.attn.c_proj.bias': array(1.3765931e-08, dtype=float32),
#  '18.ln_2.weight': array(8.835996e-06, dtype=float32),
#  '18.ln_2.bias': array(3.5269052e-06, dtype=float32),
#  '18.mlp.c_fc.weight': array(2.7189708e-06, dtype=float32),
#  '18.mlp.c_fc.bias': array(2.5019796e-07, dtype=float32),
#  '18.mlp.c_proj.weight': array(2.9473747e-06, dtype=float32),
#  '18.mlp.c_proj.bias': array(1.43274335e-08, dtype=float32),
#  '19.ln_1.weight': array(2.6841733e-06, dtype=float32),
#  '19.ln_1.bias': array(3.8654425e-06, dtype=float32),
#  '19.attn.c_attn.weight': array(3.7784039e-06, dtype=float32),
#  '19.attn.c_attn.bias': array(2.573052e-07, dtype=float32),
#  '19.attn.c_proj.weight': array(1.7181413e-06, dtype=float32),
#  '19.attn.c_proj.bias': array(1.3621106e-08, dtype=float32),
#  '19.ln_2.weight': array(2.7487101e-06, dtype=float32),
#  '19.ln_2.bias': array(3.5298544e-06, dtype=float32),
#  '19.mlp.c_fc.weight': array(2.8902243e-06, dtype=float32),
#  '19.mlp.c_fc.bias': array(2.549622e-07, dtype=float32),
#  '19.mlp.c_proj.weight': array(3.1031868e-06, dtype=float32),
#  '19.mlp.c_proj.bias': array(1.4061141e-08, dtype=float32),
#  '20.ln_1.weight': array(1.9369118e-06, dtype=float32),
#  '20.ln_1.bias': array(2.626344e-06, dtype=float32),
#  '20.attn.c_attn.weight': array(2.2653453e-06, dtype=float32),
#  '20.attn.c_attn.bias': array(1.6283516e-07, dtype=float32),
#  '20.attn.c_proj.weight': array(2.090091e-06, dtype=float32),
#  '20.attn.c_proj.bias': array(1.3719259e-08, dtype=float32),
#  '20.ln_2.weight': array(2.8268566e-06, dtype=float32),
#  '20.ln_2.bias': array(3.7505768e-06, dtype=float32),
#  '20.mlp.c_fc.weight': array(3.0896445e-06, dtype=float32),
#  '20.mlp.c_fc.bias': array(2.557675e-07, dtype=float32),
#  '20.mlp.c_proj.weight': array(3.0594813e-06, dtype=float32),
#  '20.mlp.c_proj.bias': array(1.3938298e-08, dtype=float32),
#  '21.ln_1.weight': array(3.3048013e-06, dtype=float32),
#  '21.ln_1.bias': array(2.7680198e-06, dtype=float32),
#  '21.attn.c_attn.weight': array(3.767358e-06, dtype=float32),
#  '21.attn.c_attn.bias': array(2.3668186e-07, dtype=float32),
#  '21.attn.c_proj.weight': array(2.8211257e-06, dtype=float32),
#  '21.attn.c_proj.bias': array(1.3709648e-08, dtype=float32),
#  '21.ln_2.weight': array(2.1886551e-06, dtype=float32),
#  '21.ln_2.bias': array(3.4768302e-06, dtype=float32),
#  '21.mlp.c_fc.weight': array(2.5614725e-06, dtype=float32),
#  '21.mlp.c_fc.bias': array(2.235749e-07, dtype=float32),
#  '21.mlp.c_proj.weight': array(2.5576364e-06, dtype=float32),
#  '21.mlp.c_proj.bias': array(1.344971e-08, dtype=float32),
#  '22.ln_1.weight': array(1.1630747e-06, dtype=float32),
#  '22.ln_1.bias': array(1.6534382e-06, dtype=float32),
#  '22.attn.c_attn.weight': array(1.7350736e-06, dtype=float32),
#  '22.attn.c_attn.bias': array(1.18601534e-07, dtype=float32),
#  '22.attn.c_proj.weight': array(1.409753e-06, dtype=float32),
#  '22.attn.c_proj.bias': array(1.3386632e-08, dtype=float32),
#  '22.ln_2.weight': array(2.993925e-06, dtype=float32),
#  '22.ln_2.bias': array(4.390831e-06, dtype=float32),
#  '22.mlp.c_fc.weight': array(2.1731478e-06, dtype=float32),
#  '22.mlp.c_fc.bias': array(2.122432e-07, dtype=float32),
#  '22.mlp.c_proj.weight': array(2.1584476e-06, dtype=float32),
#  '22.mlp.c_proj.bias': array(1.2739082e-08, dtype=float32),
#  '23.ln_1.weight': array(1.0661421e-06, dtype=float32),
#  '23.ln_1.bias': array(1.6289422e-06, dtype=float32),
#  '23.attn.c_attn.weight': array(2.4905228e-06, dtype=float32),
#  '23.attn.c_attn.bias': array(1.6356101e-07, dtype=float32),
#  '23.attn.c_proj.weight': array(1.3424657e-06, dtype=float32),
#  '23.attn.c_proj.bias': array(1.2623149e-08, dtype=float32),
#  '23.ln_2.weight': array(3.909097e-06, dtype=float32),
#  '23.ln_2.bias': array(4.829701e-06, dtype=float32),
#  '23.mlp.c_fc.weight': array(2.217959e-06, dtype=float32),
#  '23.mlp.c_fc.bias': array(2.078597e-07, dtype=float32),
#  '23.mlp.c_proj.weight': array(3.1012503e-06, dtype=float32),
#  '23.mlp.c_proj.bias': array(1.2266717e-08, dtype=float32)}

# %%
df['0.ln_1.weight']
# Out:
# 0    0.15052631
# Name: 0.ln_1.weight, dtype: object
